# %% [markdown]
# # Lab I
# ---
# Using the data located here: `lic = "s3://tmpnotebooks/lic.txt"`
#
# ## Goal
# The goal of this lab is to begin to become comfortable with wrangling RDDs and learning the basic RDD API. Ultimately, we want to count the words in a RDD and have output like the following,
# ```python
# In [1]: <your-code-here>
#
# Out[1]: [(u'OR', 7),
#          (u'THE', 6),
#          (u'IN', 4),
#          (u'OF', 4),
#          (u'SOFTWARE', 3),
#          (u'FOR', 2),
#          (u'IS', 2),
#          (u'OTHER', 2),
#          (u'ANY', 2),
#          (u'WARRANTY', 1),
#          (u'USE', 1),
#          (u'COPYRIGHT', 1),
#          (u'WHETHER', 1),
#          (u'BUT', 1),
#          (u'HOLDERS', 1),
#          (u'WITH', 1),
#          (u'KIND', 1),
#          ...
# ```
#
# ## 1.
# Begin by reading the file into a RDD.
#
# You can use the spark context from the spark session (avaiable at `spark.sparkContext`) to read the file into a RDD.
#
# ## 2.
# Use a `flatMap` to parse the rdd into what looks like a list of words. Create a function that will do this.
# ```python
# [u'THE',
#  u'SOFTWARE',
#  u'IS',
#  ...
# ```
#
# ## 3.
# Strip any punctuation from the words. Do this however you think is best, by creating a function and applying it to the RDD by using a map.
#
# ## 4.
# Now, to set yourself up to better wrangle the rdd, change it from a flat RDD to a RDD that has the structure of a tuple for each entry, where the first entry in the tuple is a word and the second entry is the number 1. Create a function that does this and apply it to your RDD by using a map.
#
# ## 5.
# use the groupyByKey method to groupBy. This will now change the tuples to the following form,
# ```python
# (word, <iterator>)
# ```
#
# ## 6.
# Now, take advantage of the iterator created above and apply a sum function to it with a map.
#
# ## 7.
# Finally, sort the result by value using the `sortBy()` method and descending order. Display only the first 10
#
# ## If time allows
# Instead of groupingBy the key, replace steps 5 and 6 with a `reduceByKey()`. This is much more efficient and will not create an expensive shuffle.
